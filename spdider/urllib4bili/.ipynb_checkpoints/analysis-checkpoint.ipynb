# %%
import pandas as pd
fpath = r'./data/全站榜.全站.全部投稿.日排行/20200305'
dat=pd.read_csv(fpath,delimiter='\t',skiprows=1)

# %%
dat.head(5)
# Out:
#           aid    coin   danmaku   favorite    like   reply   share     view  \
# 0  av92901768  234120     31436     183403  372722   15208   75360  4697666
# 1  av92538024  120954      4274     119217  164403    2966   12372  1918935
# 2  av93533259  168042     69198      80694  220953   12494   10300  1723623
# 3  av93418555  108689     50122      52371  229446   15633   56749  2568439
# 4  av93605411  104741     42689      32066  241004    7430    6391  1585439
#
#      score                title
# 0  2924056      [“假如我年少有为 不自卑”]
# 1  2840316    [前方高甜！我居然看了几百遍！？]
# 2  2623935              [好 哥 哥]
# 3  1237505     [【半佛】肖战事件谁是大赢家？]
# 4  1145215   [❓  ❓  ❓ 【阅片无数37】]

# %%
dat.describe()
# Out:
#                 coin        danmaku      favorite          like  \
# count     106.000000     106.000000  1.060000e+02  1.060000e+02
# mean    62305.386792   20765.924528  6.576079e+04  1.204851e+05
# std    115844.866855   34726.275723  1.828460e+05  1.691186e+05
# min       202.000000     187.000000  1.124000e+03  4.669000e+03
# 25%      9911.000000    3303.500000  9.738000e+03  4.177125e+04
# 50%     26909.500000    8944.000000  1.727650e+04  6.632550e+04
# 75%     68112.750000   23278.000000  4.192650e+04  1.348578e+05
# max    912672.000000  235779.000000  1.244757e+06  1.462445e+06
#
#                reply          share          view         score
# count     106.000000     106.000000  1.060000e+02  1.060000e+02
# mean     6833.160377   26058.509434  1.578236e+06  6.357639e+05
# std     13033.547388   76571.770766  2.795864e+06  4.308375e+05
# min       307.000000     386.000000  1.046150e+05  3.439720e+05
# 25%      1800.250000    2863.500000  4.444898e+05  3.990602e+05
# 50%      3179.500000    5674.500000  7.828280e+05  4.973060e+05
# 75%      7108.000000   16269.750000  1.570165e+06  6.947112e+05
# max    117971.000000  702393.000000  1.867373e+07  2.924056e+06

# %%
dat.columns
# Out:
# Index(['aid', ' coin', ' danmaku', ' favorite', ' like', ' reply', ' share',
#        ' view', ' score', ' title'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
for i in [' coin', ' danmaku', ' favorite', ' like', ' reply', ' share',
       ' view', ' score']:
    fig = plt.figure(figsize=(16,9))
    plt.scatter(range(len(dat[i])), dat[i])
    plt.title(i)
    plt.show()

# %%
# 对各项求和
dsum = pd.Series(0,index=dat.index)
for i in [' coin', ' danmaku', ' favorite', ' like', ' reply', ' share',' view']:
    dsum += dat[i]
    
fig = plt.figure(figsize=(16,9))
plt.scatter(range(len(dsum)), dsum)
plt.title("sum")
plt.show()
fig = plt.figure(figsize=(16,9))
plt.scatter(range(len(dat[' score'])), dat[' score'])
plt.title("score")
plt.show()

# %% [markdown]
# ```
# # [' coin', ' danmaku', ' favorite', ' like', ' reply', ' share',' view']
# # 假定 score = p0  + p1*coin + p2*danmaku + p3*favorite + p4*like + p5*reply + p6*share + p7*view + err
# ```
# 算法：
#
# $$
# X = x_i^J |size->(m*8) \\
# \Theta = [\theta_1, \theta_2, ... \theta_8] \\
# h(\Theta)= X*\Theta^T |size->(8*1)\\
# J(\Theta) = \frac{1}{2m}\sum_{i=1}^{m}(h^i(\Theta)-y^i)^2 \\
# repeat: \theta_j := \theta_j - \alpha * \frac{{\partial J(\theta)}}{\partial \theta_j} \\
# \frac{{\partial J(\Theta)}}{\partial \theta_j} = \frac{1}{m}\sum_{i=1}^{m}((h(\Theta)-y^i)*x^i_j) (j=0,1,2 ... 8)
# $$
#
# 计算：
# 1. 归一化
# 2. 给定参数初始值，运行算法
# 3. 输出参数

# %%
tmp=dat[['aid',' coin']].copy()
tmp.loc[:,' coin'] = 1
tmp.columns=['aid','base']
theta = [1,1,1,1,1,1,1]
tmp = pd.merge(tmp,dat,on='aid')

keys=['base',' coin', ' danmaku', ' favorite', ' like', ' reply', ' share',' view', ' score']
tmp = tmp[keys]
new_keys = ['base','coin', 'danmaku', 'favorite', 'like', 'reply', 'share','view', 'score'] # 去掉空格
tmp.columns=new_keys
tmp.head()
# Out:
#    base    coin  danmaku  favorite    like  reply  share     view    score
# 0     1  234120    31436    183403  372722  15208  75360  4697666  2924056
# 1     1  120954     4274    119217  164403   2966  12372  1918935  2840316
# 2     1  168042    69198     80694  220953  12494  10300  1723623  2623935
# 3     1  108689    50122     52371  229446  15633  56749  2568439  1237505
# 4     1  104741    42689     32066  241004   7430   6391  1585439  1145215

# %%
tmp.describe()
# Out:
#         base           coin        danmaku      favorite          like  \
# count  106.0     106.000000     106.000000  1.060000e+02  1.060000e+02
# mean     1.0   62305.386792   20765.924528  6.576079e+04  1.204851e+05
# std      0.0  115844.866855   34726.275723  1.828460e+05  1.691186e+05
# min      1.0     202.000000     187.000000  1.124000e+03  4.669000e+03
# 25%      1.0    9911.000000    3303.500000  9.738000e+03  4.177125e+04
# 50%      1.0   26909.500000    8944.000000  1.727650e+04  6.632550e+04
# 75%      1.0   68112.750000   23278.000000  4.192650e+04  1.348578e+05
# max      1.0  912672.000000  235779.000000  1.244757e+06  1.462445e+06
#
#                reply          share          view         score
# count     106.000000     106.000000  1.060000e+02  1.060000e+02
# mean     6833.160377   26058.509434  1.578236e+06  6.357639e+05
# std     13033.547388   76571.770766  2.795864e+06  4.308375e+05
# min       307.000000     386.000000  1.046150e+05  3.439720e+05
# 25%      1800.250000    2863.500000  4.444898e+05  3.990602e+05
# 50%      3179.500000    5674.500000  7.828280e+05  4.973060e+05
# 75%      7108.000000   16269.750000  1.570165e+06  6.947112e+05
# max    117971.000000  702393.000000  1.867373e+07  2.924056e+06

# %%
## 归一化
# (x-mean)/(max-min)
tmp = (tmp-tmp.mean())/(tmp.max()-tmp.min())
tmp['base'] = 1
tmp.head()
# Out:
#    base      coin   danmaku  favorite      like     reply     share      view  \
# 0     1  0.188296  0.045290  0.094596  0.173029  0.071176  0.070229  0.167990
# 1     1  0.064275 -0.070002  0.042984  0.030127 -0.032866 -0.019496  0.018348
# 2     1  0.115880  0.205576  0.012008  0.068919  0.048110 -0.022448  0.007829
# 3     1  0.050833  0.124606 -0.010767  0.074745  0.074788  0.043718  0.053325
# 4     1  0.046506  0.093055 -0.027094  0.082673  0.005072 -0.028016  0.000388
#
#       score
# 0  0.886906
# 1  0.854450
# 2  0.770584
# 3  0.233225
# 4  0.197455

# %%
feature_keys = ['base','coin', 'danmaku', 'favorite', 'like', 'reply', 'share','view']
feature_value = tmp[feature_keys].copy()
score = tmp['score'].copy()
theta = [1.,1.,1.,1.,1.,1.,1.,1.]

# %%
hpy=feature_value.dot(theta)

# %%
diff = hpy-score
sum(feature_value['danmaku']*diff)
# Out:
# 11.434509693586081

# %%
i = 0
alpha = 0.01
for key in feature_keys:
    print(key)
    theta[i] = theta[i] - alpha*sum(feature_value[key]*diff)/len(diff)
    i += 1
# Out:
# base
# coin
# danmaku
# favorite
# like
# reply
# share
# view

# %%
def bgd(var_dat,res_dat,alpha,theta=None):
    """
    var_dat: 变量数据集
    res_dat: 因变量数据集
    alpha: learning rate 学习率参数
    theta: 变量系数的初始值, 默认为1
    """
    # batch_gradient _descent 批量梯度下降
    if theta == None:
        theta = [i/i for i in range(1,var_dat.shape[1]+1)]
    diff=var_dat.dot(theta)-res_dat
    i=0
#     求各项的参数
    for key in var_dat.columns:
#         print(key)
        theta[i] = theta[i]-alpha*sum(var_dat[key]*diff)/len(diff)
        i+=1
    cost = sum(diff**2)/len(diff)/2 # 损失函数值
    return (theta,cost)  # 返回新的参数列表及此时的损失函数值
# new_theta,cost = bgd(feature_value,score,alpha)

# %%
print(new_theta)
print(cost)
# Out:
# [0.9509900499, 0.9960153696817449, 0.9946164383216591, 0.99558827382289, 0.9962101116264189, 0.9961459557676036, 0.9958932623373907, 0.9944011238161207]
# 0.778441203048221

# %%
for i in range(5000):
    new_theta,cost = bgd(feature_value,score,alpha,new_theta)
print(new_theta)
print(cost)
# Out:
# [2.08762358679527e-17, 0.3627526584643328, -0.0972038074217354, 0.22361046094323658, 0.3094179894638237, 0.17793978046560938, -0.48102093381060607, -0.2307514885055174]
# 0.011948411503323

# %%
# pre_data=feature_value.dot(new_theta)
# Out:
# [0.93206534790699,
#  0.9944267679901629,
#  0.9924700530136344,
#  0.9938293781692312,
#  0.9946991167183793,
#  0.9946093192075859,
#  0.994255759234841,
#  0.9921688426777606]

# %%
dat.sort_values(by=' score')
# Out:
#            aid    coin   danmaku   favorite    like   reply   share     view  \
# 99  av93130677   40170     22892      18668   54536    1738    3205   405726
# 98  av92978247    7125      1614      34957   62622    2158   63403  1717088
# 97  av93672853    7151      6143       2108   46591    1829    1639   423529
# 96  av93037768    1473      4327       4335   16692    1632    4313   518655
# 95  av93427793    8116     21947       3760   60499    2591    1554   847975
# ..         ...     ...       ...        ...     ...     ...     ...      ...
# 4   av93605411  104741     42689      32066  241004    7430    6391  1585439
# 3   av93418555  108689     50122      52371  229446   15633   56749  2568439
# 2   av93533259  168042     69198      80694  220953   12494   10300  1723623
# 1   av92538024  120954      4274     119217  164403    2966   12372  1918935
# 0   av92901768  234120     31436     183403  372722   15208   75360  4697666
#
#       score                          title
# 99   343972        [卡通配乐进化史 (1928 - 2020)]
# 98   344413                   [这波爆炸屁什么水平？]
# 97   344615   [深夜在家撸串，边烤边吃，自己做居然比外面卖的还要贵！]
# 96   344982               [“别哭，你家哥哥马上就糊了”]
# 95   347110    [【大仙全家桶】苦练李白一通宵，我已经不是昨天的我了]
# ..      ...                            ...
# 4   1145215             [❓  ❓  ❓ 【阅片无数37】]
# 3   1237505               [【半佛】肖战事件谁是大赢家？]
# 2   2623935                        [好 哥 哥]
# 1   2840316              [前方高甜！我居然看了几百遍！？]
# 0   2924056                [“假如我年少有为 不自卑”]
#
# [106 rows x 10 columns]

# %%
dat.set_index('aid')
dat.head()
# Out:
#                    aid    coin   danmaku   favorite    like   reply   share  \
# aid
# av92901768  av92901768  234120     31436     183403  372722   15208   75360
# av92538024  av92538024  120954      4274     119217  164403    2966   12372
# av93533259  av93533259  168042     69198      80694  220953   12494   10300
# av93418555  av93418555  108689     50122      52371  229446   15633   56749
# av93605411  av93605411  104741     42689      32066  241004    7430    6391
#
#                view    score                title
# aid
# av92901768  4697666  2924056      [“假如我年少有为 不自卑”]
# av92538024  1918935  2840316    [前方高甜！我居然看了几百遍！？]
# av93533259  1723623  2623935              [好 哥 哥]
# av93418555  2568439  1237505     [【半佛】肖战事件谁是大赢家？]
# av93605411  1585439  1145215   [❓  ❓  ❓ 【阅片无数37】]

# %%
plt.plot([1,2,3,4])
plt.show()
